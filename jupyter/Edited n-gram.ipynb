# %%
import pandas as pd
import matplotlib as mp
import seaborn as sb
import numpy as np

n_gram = pd.read_csv('n_gram.csv', names=["Word", "Count"])
n_gram.drop(index=[80, 81, 89, 97, 117, 119, 123, 139, 157, 166, 178, 181, 186, 205, 212, 216, 262, 265, 268, 300, 
                   319, 358, 371, 380, 381, 411, 416, 422, 512, 558, 578, 586, 650, 658, 729, 761, 783, 881, 882, 
                   827, 861, 885, 925, 937, 945, 948
                  ], inplace=True)
n_gram = n_gram[:1000]
n_gram.tail
#n_gram.to_csv('edited_n_gram.csv')
# Out:
#                 Word     Count
# 996            Doing  80821946
# 997            Loans  80821333
# 998            Shoes  80755612
# 999            Entry  80717798
# 1000            Stay  80694073
# 1001          Nature  80659036
# 1002          Orders  80605361
# 1003    Availability  80583907
# 1004          Africa  80566883
# 1005         Summary  80526622
# 1006            Turn  80328029
# 1007            Mean  80312172
# 1008          Growth  79998480
# 1009           Notes  79958318
# 1010          Agency  79915539
# 1011            King  79791224
# 1012          Monday  79697206
# 1013        European  79665774
# 1014        Activity  79633609
# 1015            Copy  79615682
# 1016        Although  79579407
# 1017            Drug  79424420
# 1018            Pics  79323162
# 1019         Western  79255339
# 1020          Income  79240506
# 1021           Force  79199815
# 1022            Cash  79172952
# 1023      Employment  79105156
# 1024         Overall  78992643
# ...
